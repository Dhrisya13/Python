# %%
# create rectangle class with attributes length and breadth and methods to find area and perimeter.
# compare two rectangle objects by their area.

class rectangle:
    def get(self,l,b):
        self.l=l
        self.b=b
    def area(self,l,b):
        return self.l*self.b
    def perimeter(self,l,b):
        return 2*(self.l+self.b)
l1=int(input("Enter the length of first rectangle:"))
b1=int(input("Enter the breadth of first rectangle:"))
l2=int(input("Enter the length of second rectangle:"))
b2=int(input("Enter the breadth of second rectangle:"))
r1=rectangle()
r1.get(l1,b1)
r2=rectangle()
r2.get(l2,b2)
p=r1.area(l1,b1)
q=r2.area(l2,b2)
r=r3.perimeter(l1,b1)
s=r4.perimeter(l2,b2)
print("Area of first rectangle:", p)
print("Area of second rectangle:", q)
print("perimeter of first rectangle:", r)
print("perimeter of second rectangle:", s)
if(p>q):
    print("Rectangle 1 is greater")
elif(p<q):
    print("Rectangle 2 is greater")
else:
    print("Rectangles are equal")
# Out:
# Enter the length of first rectangle:4
# Enter the breadth of first rectangle:6
# Enter the length of second rectangle:5
# Enter the breadth of second rectangle:8
# Area of first rectangle: 24
# Area of second rectangle: 40
# perimeter of first rectangle: 20
# perimeter of second rectangle: 26
# Rectangle 2 is greater
