# %%
# Write a python program to read a file line by line and store it into a list.
with open("sample.txt","r")as file:
    lines=file.readlines()
print("Lines in file:")
print(lines)
# Out:
# Lines in file:
# ['Python is fun\n', 'File handling is easy\n', 'practice males perfect']

# %%
# Python program to copy odd lines of one file to other.
file1=input("Enter the source file:")
file2=input("Enter the destination file:")
f1=open(file1,"r")
f2=open(file2,"w")

i=0
for line in f1.readlines():
    i=i+1
    if i%2==0:
        continue
    f2.write(line)
    
f1.close()
f2.close()
print("Odd lines copied successfully from",file1,"to",file2)
# Out:
# Enter the source file:sample.txt
# Enter the destination file:sample2.txt
# Odd lines copied successfully from sample.txt to sample2.txt

# %%
#WAPP to read each row from a given csv file and print a list of strings.
import csv
file=input("Enter the csv file name:")
f1=open(file,'r')
reader=csv.reader(f1)
for i in reader:
    print(i)
f1.close()
# Out:
# Enter the csv file name:strings.csv
# ['Name', 'Age', 'Marks']
# ['Anu', '22', '50']
# ['Arun', '21', '70']
# ['Meera', '23', '90']

# %%
#WAPP to read specific columns of a given csv file and print the content of the columns.
import csv
file=input("Enter the csv file name:")
with open(file,'r') as f1:
    reader=csv.DictReader(f1)
    
    print("\nDepartment Details:")
    print("---------------------")
    for i in reader:
        print("DeptId:",i['DeptId'],"\tDeptName:",i['DeptName'],"\tLocation:",i['Location'])
# Out:
# Enter the csv file name:Deprtment.csv
#
# Department Details:
# ---------------------
# DeptId: 101 	DeptName: Maths 	Location: BlockA
# DeptId: 102 	DeptName: Computer Science 	Location: BlockF
# DeptId: 103 	DeptName: Physics 	Location: BlockL

# %%
#WAPP to write a Python Dictionary to a csv.After writing the csv file read the csv file and display the content.
data=[{"Name":"Anu","Age":22,"Marks":50},
     {"Name":"Arun","Age":21,"Marks":60},
     {"Name":"Meera","Age":24,"Marks":80}]
with open("Dictionary.csv",'w',newline='') as file:
    fieldnames=["Name","Age","Marks"]
    writer=csv.DictWriter(file,fieldnames=fieldnames)
    writer.writeheader()
    writer.writerows(data)
print("Dictionary data Written Successfully!")

with open("Dictionary.csv",'r') as file:
    reader=csv.reader(file)
    for i in reader:
        print(i)
# Out:
# Dictionary data Written Successfully!
# ['Name', 'Age', 'Marks']
# ['Anu', '22', '50']
# ['Arun', '21', '60']
# ['Meera', '24', '80']
